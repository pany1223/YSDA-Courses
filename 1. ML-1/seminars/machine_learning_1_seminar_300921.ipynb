# %% [markdown]
# # Занятие 4. Введение в Машинное обучение
#
# **Цель данного занятия** заключается в том, что бы научить вас работать с табличными данными с использованием модуля [pandas](https://pandas.pydata.org/), а также делать агрегаты и визуализировать их, что бы вы могли лучше понять природу тех данных, с которыми работаете.
#
# ## Чтение таблицы
#
# Далее **загрузим таблицу** `Netflix.csv`, которая содержит информацию о статьях, опубликованных в различных изданиях.
#
# Для загрузки данных из csv-таблиц используется метод [pandas.read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
import pandas as pd

table = pd.read_csv('Netflix.csv')

# %% [markdown]
# Для того, что бы посмотреть на первые несколько строк таблицы, с которой вы начинаете работать, воспользуйтесь методом [pandas.DataFrame.head](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html)

# %%
table.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# Данная таблица содержит следующие колонки:
#
#     show_id : идентификатор для каждого фильма/ шоу
#
#     type : Movie или TV Show
#
#     title : заголовок
#
#     director : имя режиссёра
#
#     cast : задействованные актёры
#
#     country : страна где фильм/ шоу продюссировалось
#
#     date_added : дата добавления на Netflix
#
#     release_year : год релиза фильма/ шоу
#
#     rating : телевизионный рейтинг
#
#     duration : продолжительность в минутах или в числе сезонов
#
#     listed_in : набор тэгов
#
#     description : описание

# %% [markdown]
# Видим, что в таблицы содержится идентификатор для каждого фильма/ шоу. Далее будем использовать его в качестве индекса таблицы.
#
# Для этого можно воспользоваться методом [pandas.DataFrame.set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html), если таблица уже прочитана.

# %%
table = table.set_index('show_id')#, inplace=True)

# %% [markdown]
# **Вопрос**: Для чего мы сменили значение аргумента `inplace` на `True` (по умолчанию `False`)?

# %% [markdown]
# Также мы можем указать, какую колонку хотим использовать в качестве индекса в момент прочтения таблицы, передав индекс нужной колонки в качестве аргумента `index_col`.

# %%
table = pd.read_csv('Netflix.csv', index_col=0)

table.head(3)
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show         Blood & Water              NaN
# s3       TV Show             Ganglands  Julien Leclercq
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...

# %% [markdown]
# ## Работа с пропусками
#
# Теперь с помощью метода [pandas.DataFrame.isna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isna.html) посмотрим, в каких столбцах есть пропущенные значения,
#
# а также посчитаем их количество с помощью метода [pandas.Series.sum](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.sum.html?highlight=sum#pandas.Series.sum).

# %%
for column in table.columns:
    print(f'{column.upper()}: {table[column].isna().sum()}')
    
print(f'\nTotal rows: {len(table)}')
# Out:
# TYPE: 0
# TITLE: 0
# DIRECTOR: 2634
# CAST: 825
# COUNTRY: 831
# DATE_ADDED: 10
# RELEASE_YEAR: 0
# RATING: 4
# DURATION: 3
# LISTED_IN: 0
# DESCRIPTION: 0
#
# Total rows: 8807

# %% [markdown]
# ### Столбцы `duration` и `rating`
#
# Выведем на экран все строчки, в которых пропущены значение в стобце `duration` или `rating`,
#
# используя методы [pandas.DataFrame.isna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isna.html) и [pandas.DataFrame.any](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.any.html?highlight=any#pandas.DataFrame.any)

# %%
flags = table[['duration', 'rating']].isna().any(axis=1)

table[flags]
# Out:
#             type                                              title  \
# show_id
# s5542      Movie                                    Louis C.K. 2017
# s5795      Movie                              Louis C.K.: Hilarious
# s5814      Movie               Louis C.K.: Live at the Comedy Store
# s5990      Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# s6828    TV Show                  Gargantia on the Verdurous Planet
# s7313    TV Show                                       Little Lunch
# s7538      Movie                               My Honor Was Loyalty
#
#                 director                                               cast  \
# show_id
# s5542         Louis C.K.                                         Louis C.K.
# s5795         Louis C.K.                                         Louis C.K.
# s5814         Louis C.K.                                         Louis C.K.
# s5990                NaN                        Oprah Winfrey, Ava DuVernay
# s6828                NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# s7313                NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# s7538    Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#                country          date_added  release_year  rating  duration  \
# show_id
# s5542    United States       April 4, 2017          2017  74 min       NaN
# s5795    United States  September 16, 2016          2010  84 min       NaN
# s5814    United States     August 15, 2016          2015  66 min       NaN
# s5990              NaN    January 26, 2017          2017     NaN    37 min
# s6828            Japan    December 1, 2016          2013     NaN  1 Season
# s7313        Australia    February 1, 2018          2015     NaN  1 Season
# s7538            Italy       March 1, 2017          2015     NaN   115 min
#
#                                     listed_in  \
# show_id
# s5542                                  Movies
# s5795                                  Movies
# s5814                                  Movies
# s5990                                  Movies
# s6828    Anime Series, International TV Shows
# s7313                   Kids' TV, TV Comedies
# s7538                                  Dramas
#
#                                                description
# show_id
# s5542    Louis C.K. muses on religion, eternal love, gi...
# s5795    Emmy-winning comedy writer Louis C.K. brings h...
# s5814    The comic puts his trademark hilarious/thought...
# s5990    Oprah Winfrey sits down with director Ava DuVe...
# s6828    After falling through a wormhole, a space-dwel...
# s7313    Adopting a child's perspective, this show take...
# s7538    Amid the chaos and horror of World War II, a c...

# %% [markdown]
# Видим, что в первых трёх строчках перепутаны местами `duration` и `rating`. Получается, что во всех данных случаях пропущен именно рейтинг.
#
# Сначала востановим правильный порядок значений в первых трёх строчках, используя [pandas.DataFrame.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html?highlight=loc#pandas.DataFrame.loc)

# %%
import numpy as np

indexes = table[table['duration'].isna()].index#['s5542', 's5795', 's5814']

table.loc[indexes, 'duration'] = table.loc[indexes, 'rating']
table.loc[indexes, 'rating'] = np.nan

# %%
table[flags]
# Out:
#             type                                              title  \
# show_id
# s5542      Movie                                    Louis C.K. 2017
# s5795      Movie                              Louis C.K.: Hilarious
# s5814      Movie               Louis C.K.: Live at the Comedy Store
# s5990      Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# s6828    TV Show                  Gargantia on the Verdurous Planet
# s7313    TV Show                                       Little Lunch
# s7538      Movie                               My Honor Was Loyalty
#
#                 director                                               cast  \
# show_id
# s5542         Louis C.K.                                         Louis C.K.
# s5795         Louis C.K.                                         Louis C.K.
# s5814         Louis C.K.                                         Louis C.K.
# s5990                NaN                        Oprah Winfrey, Ava DuVernay
# s6828                NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# s7313                NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# s7538    Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#                country          date_added  release_year rating  duration  \
# show_id
# s5542    United States       April 4, 2017          2017    NaN    74 min
# s5795    United States  September 16, 2016          2010    NaN    84 min
# s5814    United States     August 15, 2016          2015    NaN    66 min
# s5990              NaN    January 26, 2017          2017    NaN    37 min
# s6828            Japan    December 1, 2016          2013    NaN  1 Season
# s7313        Australia    February 1, 2018          2015    NaN  1 Season
# s7538            Italy       March 1, 2017          2015    NaN   115 min
#
#                                     listed_in  \
# show_id
# s5542                                  Movies
# s5795                                  Movies
# s5814                                  Movies
# s5990                                  Movies
# s6828    Anime Series, International TV Shows
# s7313                   Kids' TV, TV Comedies
# s7538                                  Dramas
#
#                                                description
# show_id
# s5542    Louis C.K. muses on religion, eternal love, gi...
# s5795    Emmy-winning comedy writer Louis C.K. brings h...
# s5814    The comic puts his trademark hilarious/thought...
# s5990    Oprah Winfrey sits down with director Ava DuVe...
# s6828    After falling through a wormhole, a space-dwel...
# s7313    Adopting a child's perspective, this show take...
# s7538    Amid the chaos and horror of World War II, a c...

# %% [markdown]
# **Вопрос**: Что будем делать с данными пропусками? Почему?

# %% [markdown]
# Удалим данные строчки используя [pandas.DataFrame.notna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.notna.html#pandas.DataFrame.notna)

# %%
table = table[table['rating'].notna()]

# %% [markdown]
# ### Столбец `date_added`
#
# Выведем на экран все строчки, в которых пропущены значение в стобце `date_added`, используя метод [pandas.Series.isna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.isna.html?highlight=isna#pandas.Series.isna)

# %%
flags = table['date_added'].isna()

table[flags]
# Out:
#             type                                        title director  \
# show_id
# s6067    TV Show  A Young Doctor's Notebook and Other Stories      NaN
# s6175    TV Show              Anthony Bourdain: Parts Unknown      NaN
# s6796    TV Show                                      Frasier      NaN
# s6807    TV Show                                      Friends      NaN
# s6902    TV Show                              Gunslinger Girl      NaN
# s7197    TV Show                                     Kikoriki      NaN
# s7255    TV Show                          La Familia P. Luche      NaN
# s7407    TV Show                                        Maron      NaN
# s7848    TV Show                                 Red vs. Blue      NaN
# s8183    TV Show                 The Adventures of Figaro Pho      NaN
#
#                                                       cast         country  \
# show_id
# s6067    Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# s6175                                     Anthony Bourdain   United States
# s6796    Kelsey Grammer, Jane Leeves, David Hyde Pierce...   United States
# s6807    Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
# s6902    Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...           Japan
# s7197                                        Igor Dmitriev             NaN
# s7255    Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...   United States
# s7407    Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# s7848    Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# s8183    Luke Jurevicius, Craig Behenna, Charlotte Haml...       Australia
#
#         date_added  release_year rating    duration  \
# show_id
# s6067          NaN          2013  TV-MA   2 Seasons
# s6175          NaN          2018  TV-PG   5 Seasons
# s6796          NaN          2003  TV-PG  11 Seasons
# s6807          NaN          2003  TV-14  10 Seasons
# s6902          NaN          2008  TV-14   2 Seasons
# s7197          NaN          2010   TV-Y   2 Seasons
# s7255          NaN          2012  TV-14   3 Seasons
# s7407          NaN          2016  TV-MA   4 Seasons
# s7848          NaN          2015     NR  13 Seasons
# s8183          NaN          2015  TV-Y7   2 Seasons
#
#                                                  listed_in  \
# show_id
# s6067             British TV Shows, TV Comedies, TV Dramas
# s6175                                           Docuseries
# s6796                       Classic & Cult TV, TV Comedies
# s6807                       Classic & Cult TV, TV Comedies
# s6902                         Anime Series, Crime TV Shows
# s7197                                             Kids' TV
# s7255    International TV Shows, Spanish-Language TV Sh...
# s7407                                          TV Comedies
# s7848    TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# s8183                                Kids' TV, TV Comedies
#
#                                                description
# show_id
# s6067    Set during the Russian Revolution, this comic ...
# s6175    This CNN original series has chef Anthony Bour...
# s6796    Frasier Crane is a snooty but lovable Seattle ...
# s6807    This hit sitcom follows the merry misadventure...
# s6902    On the surface, the Social Welfare Agency appe...
# s7197    A wacky rabbit and his gang of animal pals hav...
# s7255    This irreverent sitcom featues Ludovico, Feder...
# s7407    Marc Maron stars as Marc Maron, who interviews...
# s7848    This parody of first-person shooter games, mil...
# s8183    Imagine your worst fears, then multiply them: ...

# %% [markdown]
# Мы можем также удалить данные записи, так как эта группа не является многочисленной.
#
# Но только посмотрите, здесь же сериал **Friends** ;-) Давайте придумаем, что-то ещё!
#
# **Вопрос**: Как можно востановить данные пропуски?

# %% [markdown]
# Давайте считать, что на Netflix данные сериалы были добавлены 31 декабря в год релиза, и
#
# сделаем соответсвующее заполнение воспользовавщись приёмами, рассмотренными ранее, а также [pandas.Series.apply](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.apply.html?highlight=apply#pandas.Series.apply)

# %%
indexes = table[flags].index

table.loc[indexes, 'date_added'] = table.loc[indexes,'release_year'].apply(lambda x: f'December 31, {x}')

# %% [markdown]
# ### Столбец `country`

# %% [markdown]
# Пропуске в данном столбце содердатся уже в 10% данных, которые бы не хотелось терять.
#
# **Вопрос**: Может ли странна зависить от других данных в таблицы и от каких?

# %% [markdown]
# Проверим **гипотезу**, что страну можно востановить по режесёру.
#
# Для этого по всей таблицы сформируем словарь `director`:`country`

# %%
directors = table['director'].dropna().apply(lambda x: x.split(', '))

director_counts = directors.explode().value_counts()
director_counts = director_counts[director_counts > 1]

# %%
import matplotlib.pyplot as plt

plt.title('Distribution of the number of films/ TV shows produced\n by the one director (or group directors)\n')
director_counts.hist(bins=20, figsize=(10, 5))
plt.xlabel('Number of films/ TV shows')
plt.show()

# %%
unique_directors = set(director_counts.index)
flags = directors.apply(lambda x: bool(set(x) & unique_directors))
# Можно ли это записать в одну строку? Что при этом измениться?

directors = directors[flags]
countries = table.loc[directors.index, 'country']
# Можно ли выделить нужные страны, написав table[flags]['country']?

flags = countries.notna()

directors = directors[flags]
countries = countries[flags].apply(lambda x: x.split(', '))

# %%
from collections import Counter

vocabulary = dict()
for directors, countries in zip(directors, countries):
    for director in directors:
        vocabulary.setdefault(director, Counter())
        for country in countries:
            vocabulary[director][country] += 1   
            
vocabulary = {director: countries.most_common()[0][0] for director, countries in vocabulary.items()}

print(f'Lenght vocabulary: {len(vocabulary)}')
# Out:
# Lenght vocabulary: 1222

# %%
flags = table['country'].isna()
print(f'Total NaN in column `country`: {flags.sum()}')
# Out:
# Total NaN in column `country`: 830

# %%
flags &= table['director'].notna()
print(f'Total NaN in column `country`: {flags.sum()}')
# Out:
# Total NaN in column `country`: 422

# %%
table.loc[flags, 'country'] = table.loc[flags, 'director'] \
                                   .apply(lambda x: x.split(', ')) \
                                   .apply(lambda x: [vocabulary[director] for director in x if director in vocabulary]) \
                                   .apply(lambda x: ', '.join(x) if x else np.nan)

# %%
flags = table['country'].isna()
print(f'Total NaN in column `country` after map: {flags.sum()}')
# Out:
# Total NaN in column `country` after map: 659

# %% [markdown]
# **Востановили 16% процентов пропусков**

# %% [markdown]
# Сколько процентов пропусков удалось востановить?
#
# Заменим оставшиеся пропуски на наиболее популярную странну, используя метод [pandas.Series.fillna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.fillna.html?highlight=fillna#pandas.Series.fillna)

# %%
table['country'].dropna().apply(lambda x: x.split(', ')).explode().value_counts()
# Out:
# United States     3728
# India             1119
# United Kingdom     808
# Canada             445
# France             397
#                   ...
# Bermuda              1
# Malawi               1
# Kazakhstan           1
# Liechtenstein        1
# Palestine            1
# Name: country, Length: 127, dtype: int64

# %%
table['country'].fillna('United States', inplace=True)

# %% [markdown]
# ### Столбец `director`
#
# Попробуем обучить [KNN](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) предсказывать режесёра для востановления пропущенных значений.
#
#     1. Выделим все строки, для которых извесны режесёры
#        Вопрос: Для чего мы их будем использовать для обучения, теста или того и другого?

# %%
X = table[table['director'].notna()]

# %% [markdown]
#     2. Определимся с тем какая задача перед нами стоит: бинарная, многоклассовая или многозначная классификация?

# %%
Y = X['director'].apply(lambda x: x.split(', '))

Y_counts = Y.explode().value_counts()
Y_counts = Y_counts[Y_counts > 2]

Y_unique = set(Y_counts.index)
Y = Y.apply(lambda x: set(x) & Y_unique)

flags = Y.apply(bool)
print(f'Total {flags.sum()} examples with popular director')
# Out:
# Total 1684 examples with popular director

# %%
Y = Y[flags]

flags = Y.apply(len) == 1
print(f'{round(flags.sum() / len(flags), 2)}% examples with one director')
# Out:
# 0.94% examples with one director

# %%
Y = Y[flags].apply(lambda x: x.pop())
X = X.loc[Y.index]

# %% [markdown]
#     3. Определимся с тем, какие признаки будем использовать для обучения, а также с их корректным представлением

# %%
X.head(1)
# Out:
#             type      title         director  \
# show_id
# s3       TV Show  Ganglands  Julien Leclercq
#
#                                                       cast country  \
# show_id
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  France
#
#                  date_added  release_year rating  duration  \
# show_id
# s3       September 24, 2021          2021  TV-MA  1 Season
#
#                                                  listed_in  \
# show_id
# s3       Crime TV Shows, International TV Shows, TV Act...
#
#                                                description
# show_id
# s3       To protect his family from a powerful drug lor...

# %% [markdown]
# Тип закодируем в качестве бинарного признака: является ли фильмом или нет.
#
# Далее посмотрим на распределение количества контента по годам:

# %%
plt.title('Number of movies/ TV by years')
X['release_year'].value_counts().sort_index(ascending=True).plot.barh(figsize=(10, 15))
plt.xlabel('Number of movies/ TV shows')
plt.ylabel('Release year')
plt.show()

# %% [markdown]
# Далее можем ограничется только рассмотрением контента, опублекованного после 2000 года

# %%
flags = X['release_year'] >= 2000

print(f'Total {flags.sum()} examples')
# Out:
# Total 1402 examples

# %%
X = X[flags]
Y = Y[flags]

# %% [markdown]
# Для кодирования даты релиза и рейтинга воспользуемся [sklearn.preprocessing.LabelBinarizer](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html).
#
# Столбцы со страной и тэгами бинаризуем с помощью [sklearn.preprocessing.MultiLabelBinarizer](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html), для этого сначала разобъём их по разделителю.

# %%
X['country'] = X['country'].apply(lambda x: x.split(', '))
X['listed_in'] = X['listed_in'].apply(lambda x: x.split(', '))

# %%
from sklearn.base import TransformerMixin
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer

class Binarizer(TransformerMixin):
    def __init__(self):
        self.year_binarizer = LabelBinarizer()
        self.rating_binarizer = LabelBinarizer()
        self.country_binarizer = MultiLabelBinarizer()
        self.tag_binarizer = MultiLabelBinarizer()
    
    def fit(self, X):
        self.year_binarizer.fit(X['release_year'])
        self.rating_binarizer.fit(X['rating'])
        self.country_binarizer.fit(X['country'])
        self.tag_binarizer.fit(X['listed_in'])
        return self
    
    def transform(self, X):
        is_movie = (X['type'] == 'Movie').astype(int)
        is_movie.rename('Movie', inplace=True)
        
        bin_year = self.year_binarizer.transform(X['release_year'])
        bin_year = pd.DataFrame(bin_year, columns=self.year_binarizer.classes_, index=X.index)
        
        bin_rating = self.rating_binarizer.transform(X['rating'])
        bin_rating = pd.DataFrame(bin_rating, columns=self.rating_binarizer.classes_, index=X.index)
        
        bin_country = self.country_binarizer.transform(X['country'])
        bin_country = pd.DataFrame(bin_country, columns=self.country_binarizer.classes_, index=X.index)
        
        bin_tag = self.tag_binarizer.transform(X['listed_in'])
        bin_tag = pd.DataFrame(bin_tag, columns=self.tag_binarizer.classes_, index=X.index)
        
        return pd.concat([is_movie, bin_year, bin_rating, bin_country, bin_tag], axis=1)

# %% [markdown]
#     4. Разобьём выборку на train и test

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
binarizer = Binarizer()

X_train = binarizer.fit_transform(X_train)
X_test = binarizer.transform(X_test)

# %% [markdown]
#     5. Обучаем модель на train

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred = knn.predict(X_test)

# %% [markdown]
#     6. Оцениваем качество на test

# %%
print('Accuracy', (Y_test == Y_pred).sum() / len(X_test), f'({len(Y.unique())} classes)')
# Out:
# Accuracy 0.12535612535612536 (371 classes)

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, Y_pred))
# Out:
#                           precision    recall  f1-score   support
#
#              Abhinay Deo       0.00      0.00      0.00         1
#         Abhishek Chaubey       0.00      0.00      0.00         2
#          Abhishek Kapoor       0.00      0.00      0.00         0
#          Abhishek Sharma       0.00      0.00      0.00         1
#               Adam McKay       0.00      0.00      0.00         2
#            Adam Shankman       0.00      0.00      0.00         1
#               Adrian Teh       0.00      0.00      0.00         1
#          Adriano Rudiman       0.33      1.00      0.50         2
#                Adze Ugah       0.00      0.00      0.00         2
#           Ahmad El-Badri       0.00      0.00      0.00         3
#           Ahmed Al-Badry       0.00      0.00      0.00         2
#        Ahmed Nader Galal       0.00      0.00      0.00         1
#           Akiva Schaffer       0.00      0.00      0.00         0
#      Alastair Fothergill       0.00      0.00      0.00         1
#             Alex Lehmann       0.00      0.00      0.00         1
#           Alexis Morante       0.00      0.00      0.00         0
#              Amitoj Mann       0.00      0.00      0.00         0
#                Amr Arafa       0.00      0.00      0.00         1
#       Andibachtiar Yusuf       0.00      0.00      0.00         0
#            Andrew Duncan       0.00      0.00      0.00         0
#     Andrew Lau Wai-Keung       0.00      0.00      0.00         1
#       Andrzej Bartkowiak       0.00      0.00      0.00         0
#             Andy Tennant       0.00      0.00      0.00         1
#             Anees Bazmee       0.00      0.00      0.00         0
#    Angga Dwimas Sasongko       0.00      0.00      0.00         1
#            Antoine Fuqua       0.00      0.00      0.00         1
#       Antoinette Jadaone       0.00      0.00      0.00         0
#           Antonio Campos       0.00      0.00      0.00         1
#              Anurag Basu       0.00      0.00      0.00         0
#           Anurag Kashyap       0.17      0.50      0.25         2
#       Ashutosh Gowariker       0.00      0.00      0.00         0
#           Asit Mohapatra       0.00      0.00      0.00         1
#             Ava DuVernay       0.00      0.00      0.00         2
#      B. V. Nandini Reddy       0.00      0.00      0.00         1
#                BB Sasore       0.00      0.00      0.00         0
#    Banjong Pisanthanakun       0.00      0.00      0.00         1
#            Barak Goodman       0.00      0.00      0.00         0
#             Barry Avrich       0.00      0.00      0.00         2
#           Barry Levinson       0.00      0.00      0.00         0
#         Barry Sonnenfeld       0.00      0.00      0.00         0
#             Bedran Güzel       0.12      1.00      0.22         1
#        Bobcat Goldthwait       0.00      0.00      0.00         1
#            Brad Anderson       0.00      0.00      0.00         1
#              Brett Haley       0.00      0.00      0.00         1
#             Brian Levant       0.00      0.00      0.00         1
#            Bruno Garotti       0.00      0.00      0.00         2
#              Burak Aksak       0.00      0.00      0.00         1
#      Cathy Garcia-Molina       0.00      0.00      0.00         1
#               Cem Yılmaz       0.00      0.00      0.00         1
#     Chandrakant Kulkarni       0.00      0.00      0.00         0
#        Charles Stone III       0.00      0.00      0.00         0
#               Chris Howe       0.25      1.00      0.40         1
#              Chris Smith       0.00      0.00      0.00         0
#             Chris Stokes       0.00      0.00      0.00         3
#              Chris Weitz       0.00      0.00      0.00         0
#       Christopher Storer       0.00      0.00      0.00         1
#                Clay Glen       0.00      0.00      0.00         2
#           Clint Eastwood       0.00      0.00      0.00         0
#            Conrad Helten       0.00      0.00      0.00         0
#             Craig Brewer       0.00      0.00      0.00         0
#           Cristina Jacob       0.00      0.00      0.00         0
#             Dan Villegas       0.00      0.00      0.00         0
#                Dante Lam       0.00      0.00      0.00         2
#               David Ayer       0.00      0.00      0.00         2
#              David Batty       1.00      1.00      1.00         1
#             David Dhawan       0.00      0.00      0.00         2
#          David Mackenzie       0.00      0.00      0.00         0
#           David R. Ellis       0.00      0.00      0.00         0
#             David Zucker       0.00      0.00      0.00         1
#             Dennis Dugan       0.00      0.00      0.00         2
#              Detlev Buck       0.00      0.00      0.00         1
#         Don Michael Paul       0.00      0.00      0.00         1
#            Drake Doremus       0.00      0.00      0.00         1
#         Edward Cotterill       0.50      1.00      0.67         1
# Elaine McMillion Sheldon       0.00      0.00      0.00         0
#                 Eli Roth       0.00      0.00      0.00         1
#             Eric Darnell       0.00      0.00      0.00         0
#          Ernie Barbarash       0.00      0.00      0.00         1
#           Ezekiel Norton       0.00      0.00      0.00         2
#               Farah Khan       0.00      0.00      0.00         1
#            Farhan Akhtar       0.00      0.00      0.00         1
#          Fernando Ayllón       1.00      0.67      0.80         3
# Fernando González Molina       0.00      0.00      0.00         0
#            Florent Bodin       0.00      0.00      0.00         0
#         Gabriele Muccino       0.00      0.00      0.00         2
#           Gajendra Ahire       0.00      0.00      0.00         1
#           Garry Marshall       0.00      0.00      0.00         0
#         Gerardo Olivares       0.00      0.00      0.00         1
#    Gilles Paquet-Brenner       0.00      0.00      0.00         0
#    Gonzalo López-Gallego       0.00      0.00      0.00         2
#        Greg MacGillivray       0.00      0.00      0.00         2
#              Hakan Algül       0.20      0.25      0.22         4
#         Hanung Bramantyo       0.00      0.00      0.00         1
#             Hardik Mehta       0.00      0.00      0.00         1
#               Hernán Zin       0.00      0.00      0.00         0
#           Hidenori Inoue       1.00      1.00      1.00         1
#         Hiroyuki Seshita       0.00      0.00      0.00         0
#               Imtiaz Ali       0.00      0.00      0.00         4
#              Indra Kumar       0.00      0.00      0.00         1
#              Ishaya Bako       0.00      0.00      0.00         1
#              Ishi Rudell       0.00      0.00      0.00         1
#            Ismail Farouk       0.00      0.00      0.00         2
#             Ivan Reitman       0.00      0.00      0.00         1
#                James Wan       0.00      0.00      0.00         1
#               Jared Hess       0.00      0.00      0.00         2
#              Jay Chapman       0.00      0.00      0.00         1
#                Jay Karas       0.00      0.00      0.00         4
#                Jay Roach       0.00      0.00      0.00         1
#             Jeff Nichols       0.00      0.00      0.00         1
#          Jeremy Saulnier       0.00      0.00      0.00         1
#         Jesse V. Johnson       0.00      0.00      0.00         2
#            Joe Berlinger       0.00      0.00      0.00         2
#                 Joe Camp       0.00      0.00      0.00         1
#                  Joey So       1.00      0.33      0.50         3
#         John Lee Hancock       0.00      0.00      0.00         1
#               Johnnie To       0.00      0.00      0.00         1
#               Jon M. Chu       0.00      0.00      0.00         2
#            Jon Rosenbaum       0.00      0.00      0.00         1
#           Jonathan Demme       0.00      0.00      0.00         1
#                 Jun Lana       0.00      0.00      0.00         3
#           Justin G. Dyck       1.00      0.50      0.67         2
#              Karan Johar       0.00      0.00      0.00         1
#         Karthik Subbaraj       0.00      0.00      0.00         0
#             Karyn Kusama       0.00      0.00      0.00         0
#             Kayode Kasum       0.25      1.00      0.40         1
#             Kemi Adetiba       0.00      0.00      0.00         2
#                Ken Burns       0.00      0.00      0.00         1
#                Ken Ghosh       0.00      0.00      0.00         1
#            Kenneth Gyang       0.00      0.00      0.00         1
#              Kevin Smith       0.00      0.00      0.00         0
#             Khaled Marei       0.00      0.00      0.00         1
#            Kief Davidson       0.00      0.00      0.00         1
#           Kunle Afolayan       1.00      0.33      0.50         3
#           Kıvanç Baruönü       0.00      0.00      0.00         1
#              Lance Bangs       0.00      0.00      0.00         4
#          Lasse Hallström       0.00      0.00      0.00         4
#             Lee Tamahori       0.00      0.00      0.00         2
#              Leena Yadav       0.00      0.00      0.00         1
#             Leigh Janiak       0.50      1.00      0.67         1
#             Les Mayfield       0.00      0.00      0.00         0
#             Leslie Small       0.00      0.00      0.00         1
#            Linda Mendoza       0.00      0.00      0.00         1
#           Lucas Margutti       1.00      1.00      1.00         1
#                 Luis Ara       1.00      0.50      0.67         2
#        Madhur Bhandarkar       0.00      0.00      0.00         2
#         Mae Czarina Cruz       0.00      0.00      0.00         2
#         Mahesh Manjrekar       0.00      0.00      0.00         2
#            Mahmoud Karim       0.00      0.00      0.00         1
#          Manny Rodriguez       0.00      0.00      0.00         1
#             Marc Forster       0.00      0.00      0.00         1
#             Marcus Raboy       0.20      0.33      0.25         3
#          Martin Campbell       0.00      0.00      0.00         1
#          Masahiko Murata       0.20      1.00      0.33         1
#               Matt Askem       0.00      0.00      0.00         5
#                      McG       0.00      0.00      0.00         2
#              Michael Bay       0.00      0.00      0.00         1
#            Michael Dowse       0.00      0.00      0.00         1
#            Michael McKay       0.00      0.00      0.00         1
#           Michael Tiddes       0.00      0.00      0.00         1
#           Michèle Ohayon       0.00      0.00      0.00         1
#         Mike Clattenburg       0.00      0.00      0.00         1
#            Mike Flanagan       0.00      0.00      0.00         2
#             Mike Gunther       0.00      0.00      0.00         3
#              Mikhail Red       0.00      0.00      0.00         1
#            Milan Luthria       0.00      0.00      0.00         2
#            Mohamed Hamdy       0.00      0.00      0.00         0
#             Mohamed Samy       0.00      0.00      0.00         1
#           Morgan Neville       0.00      0.00      0.00         1
#          Nagesh Kukunoor       0.00      0.00      0.00         2
#             Neal Brennan       0.00      0.00      0.00         0
#            Neeraj Pandey       0.00      0.00      0.00         0
#        Nila Madhab Panda       0.00      0.00      0.00         0
#             Noriyuki Abe       0.00      0.00      0.00         2
#             Obi Emelonye       0.00      0.00      0.00         1
#          Olivier Assayas       0.00      0.00      0.00         2
#              Omoni Oboli       0.00      0.00      0.00         2
#                     Onir       0.00      0.00      0.00         2
#    Orlando von Einsiedel       0.00      0.00      0.00         1
#             Ozan Açıktan       0.00      0.00      0.00         3
#           Pang Ho-cheung       0.00      0.00      0.00         2
#             Pankaj Batra       0.00      0.00      0.00         1
#             Paul Dugdale       0.00      0.00      0.00         2
#          Paul Greengrass       0.00      0.00      0.00         1
#       Paul W.S. Anderson       0.00      0.00      0.00         1
#            Peter Jackson       0.00      0.00      0.00         2
#              Peter Segal       0.00      0.00      0.00         0
#             Peter Spirer       0.00      0.00      0.00         1
#              Peyton Reed       0.00      0.00      0.00         1
#       Philippe Aractingi       0.00      0.00      0.00         3
#                Poj Arnon       0.00      0.00      0.00         0
#              Prakash Jha       0.00      0.00      0.00         0
#            Prakash Satam       0.67      1.00      0.80         2
#             Priyadarshan       0.00      0.00      0.00         3
#        Qaushiq Mukherjee       0.00      0.00      0.00         2
#        Quentin Tarantino       0.00      0.00      0.00         1
#             Raja Gosnell       0.00      0.00      0.00         1
#            Rajiv Chilaka       0.70      1.00      0.82         7
#              Rajiv Menon       0.00      0.00      0.00         2
#            Rako Prijanto       0.00      0.00      0.00         2
#          Ram Gopal Varma       0.00      0.00      0.00         1
#      Rathindran R Prasad       0.67      1.00      0.80         2
#             Renny Harlin       0.00      0.00      0.00         1
#           Ribhu Dasgupta       0.00      0.00      0.00         1
#          Ric Roman Waugh       0.00      0.00      0.00         1
#           Richard Weston       1.00      1.00      1.00         1
#                Riri Riza       0.00      0.00      0.00         2
#           Robert Luketic       0.00      0.00      0.00         1
#         Robert Rodriguez       0.50      0.33      0.40         3
#          Robert Zemeckis       0.00      0.00      0.00         1
#             Roger Kumble       0.00      0.00      0.00         3
#             Rohit Jugraj       0.00      0.00      0.00         1
#             Rohit Shetty       0.00      0.00      0.00         2
#               Ron Howard       0.00      0.00      0.00         5
#               Ron Oliver       0.00      0.00      0.00         1
#              Ryan Polito       0.00      0.00      0.00         2
#           S.S. Rajamouli       0.50      0.67      0.57         3
#                  Sam Liu       0.00      0.00      0.00         1
#          Sameh Abdulaziz       0.00      0.00      0.00         3
#           Satish Rajwade       0.00      0.00      0.00         2
#     Savage Steve Holland       0.00      0.00      0.00         1
#            Sean McNamara       0.00      0.00      0.00         1
#       Sebastián Schindel       0.00      0.00      0.00         1
#          Sermiyan Midyat       0.00      0.00      0.00         2
#             Seth Barrish       0.00      0.00      0.00         1
#            Seyi Babatope       0.00      0.00      0.00         1
#          Shannon Hartman       0.00      0.00      0.00         2
#            Shigeaki Kubo       1.00      1.00      1.00         3
#           Shirish Kunder       0.00      0.00      0.00         1
#            Shyam Benegal       0.00      0.00      0.00         1
#             Simon Wincer       0.00      0.00      0.00         1
#            Sofia Coppola       0.00      0.00      0.00         1
#           Soudade Kaadan       0.00      0.00      0.00         1
#              Stan Lathan       0.00      0.00      0.00         2
#               Steve Ball       0.00      0.00      0.00         1
#              Steve Brill       0.00      0.00      0.00         1
#               Steve Carr       0.00      0.00      0.00         2
#              Steve Sacks       0.00      0.00      0.00         1
#         Steven C. Miller       0.00      0.00      0.00         3
#        Steven Soderbergh       0.00      0.00      0.00         2
#         Steven Spielberg       0.00      0.00      0.00         2
#              Suhas Kadav       1.00      0.33      0.50         3
#              Sujoy Ghosh       0.00      0.00      0.00         1
#              Tate Taylor       0.00      0.00      0.00         1
#         Theodore Boborol       0.00      0.00      0.00         1
#           Thierry Donard       0.00      0.00      0.00         3
#           Tiller Russell       0.00      0.00      0.00         1
#            Todd Phillips       0.00      0.00      0.00         1
#             Toka McBaror       0.00      0.00      0.00         2
#               Tom Hooper       0.00      0.00      0.00         2
#        Toshiya Shinohara       0.00      0.00      0.00         3
#        Toshiyuki Kubooka       1.00      1.00      1.00         1
#     Vikramaditya Motwane       0.00      0.00      0.00         1
#           Vince Marcello       0.00      0.00      0.00         0
#       Vivieno Caldinelli       1.00      1.00      1.00         1
#               Vlad Yudin       1.00      0.33      0.50         3
#               Wael Ehsan       0.11      0.50      0.18         2
#               Wael Ihsan       0.00      0.00      0.00         1
#          Wenn V. Deramas       0.00      0.00      0.00         2
#            Werner Herzog       0.00      0.00      0.00         1
#               Wilson Yip       1.00      0.50      0.67         2
#        Wolfgang Petersen       0.00      0.00      0.00         1
#             Yasmin Ahmad       0.00      0.00      0.00         1
#           Yılmaz Erdoğan       0.00      0.00      0.00         1
#              Zoya Akhtar       0.00      0.00      0.00         1
#         Ömer Faruk Sorak       0.00      0.00      0.00         1
#
#                 accuracy                           0.13       351
#                macro avg       0.08      0.09      0.07       351
#             weighted avg       0.13      0.13      0.11       351
